# %% [markdown]
# # kMeans clustering
#
# In this lab you will separate iris species as well as you can using
# k-means clustering.  Proceed as follows:
#
# 1. load the iris data
# 2. select two features.  Plot the data, depict the (true) species as
# different colors.
# 3. perform k-means clustering.  Try different $k$-s (2,3,4,5 or so).
# Disregarding the true species, think which one gives you the best
# clustering.
# 4. repeat the exercise with different pairs of features.
# 5. pick your "favorite 2d model": the model that seems visually the
# most convincing.
# 6. Now do kmeans on all 4 features.  Compare the results with the true
# species and compute accuracy.  Note: the k-means detected cluster id-s
# may be different from the original id-s.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
% matplotlib inline
import sklearn.datasets as ds
from sklearn.cluster import KMeans
from sklearn.metrics import confusion_matrix

# %% [markdown]
# ## 1. load the data

# %%
iris = ds.load_iris()
x = iris['data'][:,:2]
# select 1st and 2nd feature
y = iris['target']

# %%
iris.keys()
# Out:
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names'])

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
print(iris.DESCR)
# Out:
# Iris Plants Database
# ...
#
# Notes
# -----
# Data Set Characteristics:
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, predictive attributes and the class
#     :Attribute Information:
#         - sepal length in cm
#         - sepal width in cm
#         - petal length in cm
#         - petal width in cm
#         - class:
#                 - Iris-Setosa
#                 - Iris-Versicolour
#                 - Iris-Virginica
#     :Summary Statistics:
#
#     ============== ==== ==== ======= ===== ====================
#                     Min  Max   Mean    SD   Class Correlation
#     ============== ==== ==== ======= ===== ====================
#     sepal length:   4.3  7.9   5.84   0.83    0.7826
#     sepal width:    2.0  4.4   3.05   0.43   -0.4194
#     petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
#     petal width:    0.1  2.5   1.20  0.76     0.9565  (high!)
# ...

# %% [markdown]
# ## 2. plot data

# %%
plt.jet()
plt.figure(figsize=(10,10))
sd = 0.02
plt.scatter(x[:,0] + np.random.normal(0, sd, 150), x[:,1] + np.random.normal(0, sd, 150), c=y, s=100)

# %% [markdown]
# ## 3. kmeans

# %%
plt.figure(figsize=(16, 25))

km = KMeans(2)
yhat = km.fit(x).labels_
mu = km.cluster_centers_
plt.subplot(3,2,1)
plt.scatter(x[:,0], x[:,1], c=yhat, alpha = 0.3)
plt.scatter(mu[:,0], mu[:,1], c= np.unique(yhat), s=100)
plt.xlabel('sepal length in cm')
plt.ylabel('sepal width (cm)')
plt.title('K=2')

km = KMeans(3)
yhat = km.fit(x).labels_
mu = km.cluster_centers_
plt.subplot(3,2,2)
plt.scatter(x[:,0], x[:,1], c=yhat, alpha = 0.3)
plt.scatter(mu[:,0], mu[:,1], c= np.unique(yhat), s=100)
plt.xlabel('sepal length in cm')
plt.ylabel('sepal width (cm)')
plt.title('K=3')

km = KMeans(4)
yhat = km.fit(x).labels_
mu = km.cluster_centers_
plt.subplot(3,2,3)
plt.scatter(x[:,0], x[:,1], c=yhat, alpha = 0.3)
plt.scatter(mu[:,0], mu[:,1], c= np.unique(yhat), s=100)
plt.xlabel('sepal length in cm')
plt.ylabel('sepal width (cm)')
plt.title('K=4')

km = KMeans(5)
yhat = km.fit(x).labels_
mu = km.cluster_centers_
plt.subplot(3,2,4)
plt.scatter(x[:,0], x[:,1], c=yhat, alpha = 0.3)
plt.scatter(mu[:,0], mu[:,1], c= np.unique(yhat), s=100)
plt.xlabel('sepal length in cm')
plt.ylabel('sepal width (cm)')
plt.title('K=5')

km = KMeans(6)
yhat = km.fit(x).labels_
mu = km.cluster_centers_
plt.subplot(3,2,5)
plt.scatter(x[:,0], x[:,1], c=yhat, alpha = 0.3)
plt.scatter(mu[:,0], mu[:,1], c= np.unique(yhat), s=100)
plt.xlabel('sepal length in cm')
plt.ylabel('sepal width (cm)')
plt.title('K=6')

km = KMeans(7)
yhat = km.fit(x).labels_
mu = km.cluster_centers_
plt.subplot(3,2,6)
plt.scatter(x[:,0], x[:,1], c=yhat, alpha = 0.3)
plt.scatter(mu[:,0], mu[:,1], c= np.unique(yhat), s=100)
plt.xlabel('sepal length in cm')
plt.ylabel('sepal width (cm)')
plt.title('K=7')
# Out:
# Text(0.5,1,'K=7')

# %% [markdown]
# ## 4. try other covariates

# %%
x1 = iris['data'][:,1:3]
plt.jet()
plt.figure(figsize=(10,10))
sd = 0.02
plt.scatter(x1[:,0] + np.random.normal(0, sd, 150), x1[:,1] + np.random.normal(0, sd, 150), c=y, s=100)

# %%
iris_df = pd.DataFrame(iris.data, columns = iris.feature_names)
x = iris_df[['sepal length (cm)', 'petal length (cm)']]

# %%
plt.figure(figsize=(16, 25))

km = KMeans(2)
yhat = km.fit(x).labels_
mu = km.cluster_centers_
plt.subplot(3,2,1)
plt.scatter(x['sepal length (cm)'], x['petal length (cm)'], c=yhat, alpha = 0.3)
plt.scatter(mu[:,0], mu[:,1], c= np.unique(yhat), s=100)
plt.xlabel('sepal length in cm')
plt.ylabel('petal length (cm)')
plt.title('K=2')

km = KMeans(3)
yhat = km.fit(x).labels_
mu = km.cluster_centers_
plt.subplot(3,2,2)
plt.scatter(x['sepal length (cm)'], x['petal length (cm)'], c=yhat, alpha = 0.3)
plt.scatter(mu[:,0], mu[:,1], c= np.unique(yhat), s=100)
plt.xlabel('sepal length in cm')
plt.ylabel('petal length (cm)')
plt.title('K=3')

km = KMeans(4)
yhat = km.fit(x).labels_
mu = km.cluster_centers_
plt.subplot(3,2,3)
plt.scatter(x['sepal length (cm)'], x['petal length (cm)'], c=yhat, alpha = 0.3)
plt.scatter(mu[:,0], mu[:,1], c= np.unique(yhat), s=100)
plt.xlabel('sepal length in cm')
plt.ylabel('petal length (cm)')
plt.title('K=4')

km = KMeans(5)
yhat = km.fit(x).labels_
mu = km.cluster_centers_
plt.subplot(3,2,4)
plt.scatter(x['sepal length (cm)'], x['petal length (cm)'], c=yhat, alpha = 0.3)
plt.scatter(mu[:,0], mu[:,1], c= np.unique(yhat), s=100)
plt.xlabel('sepal length in cm')
plt.ylabel('petal length (cm)')
plt.title('K=5')

km = KMeans(6)
yhat = km.fit(x).labels_
mu = km.cluster_centers_
plt.subplot(3,2,5)
plt.scatter(x['sepal length (cm)'], x['petal length (cm)'], c=yhat, alpha = 0.3)
plt.scatter(mu[:,0], mu[:,1], c= np.unique(yhat), s=100)
plt.xlabel('sepal length in cm')
plt.ylabel('petal length (cm)')
plt.title('K=6')

km = KMeans(7)
yhat = km.fit(x).labels_
mu = km.cluster_centers_
plt.subplot(3,2,6)
plt.scatter(x['sepal length (cm)'], x['petal length (cm)'], c=yhat, alpha = 0.3)
plt.scatter(mu[:,0], mu[:,1], c= np.unique(yhat), s=100)
plt.xlabel('sepal length in cm')
plt.ylabel('petal length (cm)')
plt.title('K=7')
# Out:
# Text(0.5,1,'K=7')

# %%
iris_df = pd.DataFrame(iris.data, columns = iris.feature_names)
x = iris_df[['sepal length (cm)', 'petal width (cm)']]

# %%
plt.figure(figsize=(16, 25))

km = KMeans(2)
yhat = km.fit(x).labels_
mu = km.cluster_centers_
plt.subplot(3,2,1)
plt.scatter(x['sepal length (cm)'], x['petal width (cm)'], c=yhat, alpha = 0.3)
plt.scatter(mu[:,0], mu[:,1], c= np.unique(yhat), s=100)
plt.xlabel('sepal length in cm')
plt.ylabel('petal width (cm)')
plt.title('K=2')

km = KMeans(3)
yhat = km.fit(x).labels_
mu = km.cluster_centers_
plt.subplot(3,2,2)
plt.scatter(x['sepal length (cm)'], x['petal width (cm)'], c=yhat, alpha = 0.3)
plt.scatter(mu[:,0], mu[:,1], c= np.unique(yhat), s=100)
plt.xlabel('sepal length in cm')
plt.ylabel('petal width (cm)')
plt.title('K=3')

km = KMeans(4)
yhat = km.fit(x).labels_
mu = km.cluster_centers_
plt.subplot(3,2,3)
plt.scatter(x['sepal length (cm)'], x['petal width (cm)'], c=yhat, alpha = 0.3)
plt.scatter(mu[:,0], mu[:,1], c= np.unique(yhat), s=100)
plt.xlabel('sepal length in cm')
plt.ylabel('petal width (cm)')
plt.title('K=4')

km = KMeans(5)
yhat = km.fit(x).labels_
mu = km.cluster_centers_
plt.subplot(3,2,4)
plt.scatter(x['sepal length (cm)'], x['petal width (cm)'], c=yhat, alpha = 0.3)
plt.scatter(mu[:,0], mu[:,1], c= np.unique(yhat), s=100)
plt.xlabel('sepal length in cm')
plt.ylabel('petal width (cm)')
plt.title('K=5')

km = KMeans(6)
yhat = km.fit(x).labels_
mu = km.cluster_centers_
plt.subplot(3,2,5)
plt.scatter(x['sepal length (cm)'], x['petal width (cm)'], c=yhat, alpha = 0.3)
plt.scatter(mu[:,0], mu[:,1], c= np.unique(yhat), s=100)
plt.xlabel('sepal length in cm')
plt.ylabel('petal width (cm)')
plt.title('K=6')

km = KMeans(7)
yhat = km.fit(x).labels_
mu = km.cluster_centers_
plt.subplot(3,2,6)
plt.scatter(x['sepal length (cm)'], x['petal width (cm)'], c=yhat, alpha = 0.3)
plt.scatter(mu[:,0], mu[:,1], c= np.unique(yhat), s=100)
plt.xlabel('sepal length in cm')
plt.ylabel('petal width in cm')
plt.title('K=7')
# Out:
# Text(0.5,1,'K=7')

# %% [markdown]
# ## 5. Pick the best

# %% [markdown]
# The best model is sepal length and petal length with k=3. The clusters can be visually seen clearly and there are gaps between clusters but not within the cluster itself.

# %% [markdown]
# ## 6. all 4 features

# %%
iris_df = pd.DataFrame(iris.data, columns = iris.feature_names)
x = iris_df[['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']]

# %%
km1 = KMeans(2)
yhat1 = km1.fit(x).labels_
mu1 = km1.cluster_centers_

km2 = KMeans(3)
yhat2 = km2.fit(x).labels_
mu2 = km2.cluster_centers_

km3 = KMeans(4)
yhat3 = km3.fit(x).labels_
mu3 = km3.cluster_centers_

km4 = KMeans(5)
yhat4 = km4.fit(x).labels_
mu4 = km4.cluster_centers_

km5 = KMeans(6)
yhat5 = km5.fit(x).labels_
mu5 = km5.cluster_centers_

km6 = KMeans(7)
yhat6 = km6.fit(x).labels_
mu6 = km6.cluster_centers_

# %%
confusion_matrix(y, yhat2)
# Out:
# array([[50,  0,  0],
#        [ 0, 48,  2],
#        [ 0, 14, 36]], dtype=int64)

# %%
((50+48+36)/150) * 100
# Out:
# 89.33333333333333
